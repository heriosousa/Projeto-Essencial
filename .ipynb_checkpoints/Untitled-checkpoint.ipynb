# %%
import pandas as pd
mge_data = pd.read_table('./deg-np-15.2/degannotation-np.dat')
mge_data
# Out:
# C:\Users\herio\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#                                            #DEG_AC #Gene_Name  \
# DNEG1001 DNEG10010001 yaaA 16077071       COG2501S          -
#          DNEG10010002 recF 16077072       COG1195L          -
#          DNEG10010003 yaaB 255767014             -          -
#          DNEG10010004 yaaC 16077076              -          -
#          DNEG10010005 dacA 16077078       COG1686M          -
#          DNEG10010006 yaaD 16077079       COG0214H          -
#          DNEG10010007 yaaE 16077080       COG0311H          -
#          DNEG10010008 dck  16077082       COG1428F          -
#          DNEG10010009 dgk  16077083       COG1428F          -
# ...
